# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk

# %%
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\EFRAIN
# [nltk_data]     LINARES\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\EFRAIN
# [nltk_data]     LINARES\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\EFRAIN
# [nltk_data]     LINARES\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\EFRAIN
# [nltk_data]     LINARES\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
Data = pd.read_parquet(r'C:\Users/EFRAIN LINARES\Desktop/Henry PI 1\PI MLOps - STEAM/PARQUET\df_review_clean.parquet')

# %%
Data
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                           posted item_id recommend  \
# ...

# %%
df_copy = Data.copy()

# %%
df_copy['review'] = df_copy['review'].replace(['10/10', '100/100'], 'excelent', regex=True)


df_copy['review'] = df_copy['review'].astype(str)

# %%
sid = SentimentIntensityAnalyzer()


stemmer = PorterStemmer()

lemmatizer = WordNetLemmatizer()

# %%
def stemming_apply (texto):
    palabras = word_tokenize(texto)
    stemmed_palabras = [stemmer.stem(word) for word in palabras]
    return ' '.join(stemmed_palabras)



df_copy['review'] = df_copy['review'].apply(stemming_apply)

# %%
def lematinazion_appy (texto):
    palabras = word_tokenize(texto)
    stemmed_palabras = [stemmer.stem(word) for word in palabras]
    return ' '.join(stemmed_palabras)



df_copy['review'] = df_copy['review'].apply(le)

# %%
def analisis_sentiment (texto, recomend):
    if pd.isnull(texto):
        return 1
    escala_sentiment = sid.polarity_scores(texto)['compound']
    if recomend:
        escala_sentiment += 0.5
    else:
        escala_sentiment -= 0.5
    if escala_sentiment <= -0.05:
        return 0
    elif escala_sentiment >= 0.05:
        return 2
    else:
        return 1


df_copy['sentiment_analisys'] = df_copy.apply(lambda row: analisis_sentiment(row['review'], row['recommend']), axis=1)

df_copy    
df_copy.drop(columns=['review'], inplace=True)

# %%
df_copy
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
positivo_nega = df_copy[(df_copy['sentiment_analisys'] == 2) & (df_copy['recommend'] == False)]

negativo_posi = df_copy[(df_copy['sentiment_analisys'] == 0) & (df_copy['recommend'] == True)]

count_positivos = len(positivo_nega)

count_negativos = len(negativo_posi)

print(f"El conteo de sentimiento negativo pero con recomendacion positiva son: {count_negativos}")

print(f"El conteo de sentimiento positivo pero con recomendacion negativa son: {count_positivos}")
# Out:
# El conteo de sentimiento negativo pero con recomendacion positiva son: 2904
# El conteo de sentimiento positivo pero con recomendacion negativa son: 1323

# %%
total_conteos = 2904 + 1323

datos_totales = 59333

porcentaje = (total_conteos/datos_totales) * 100

print(f"El porcentaje de errores son de {porcentaje}")
# Out:
# El porcentaje de errores son de 7.124197326951275

# %%
df_copy
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
df_copy.to_parquet(r'C:\Users\EFRAIN LINARES\Desktop\Henry PI 1\PI MLOps - STEAM\PARQUET\analisis_sentiment.parquet', index= False)
